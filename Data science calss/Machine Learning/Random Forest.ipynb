# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.3.5-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.3.5-cp314-cp314-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.9 MB 7.4 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.9 MB 7.7 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.9 MB 8.2 MB/s eta 0:00:01
#    ------------------- -------------------- 6.3/12.9 MB 8.1 MB/s eta 0:00:01
#    -------------------------- ------------- 8.7/12.9 MB 8.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.9 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 8.5 MB/s  0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.3.5
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\sanan\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
# My Candy List 
candies = ["Chocolate", "Gummy","Lollipop","Mint","Caramel"]
print("Original Candies:", candies)

# Pick 3 Candies Randomly (With Replacement)
sample  = np.random.choice(candies, size=3, replace=True)
print("Random sample:", sample)
# Out:
# Original Candies: ['Chocolate', 'Gummy', 'Lollipop', 'Mint', 'Caramel']
# Random sample: ['Caramel' 'Chocolate' 'Chocolate']

# %%
# %pip install scikit-learn
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp313-cp313t-win_amd64.whl.metadata (11 kB)
# Collecting numpy>=1.22.0 (from scikit-learn)
#   Downloading numpy-2.3.5-cp313-cp313t-win_amd64.whl.metadata (60 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp313-cp313t-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp313-cp313t-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------- ----------------------------- 2.4/9.3 MB 11.8 MB/s eta 0:00:01
#    --------------------- ------------------ 5.0/9.3 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 10.7 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading numpy-2.3.5-cp313-cp313t-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.9 MB 11.7 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.9 MB 10.9 MB/s eta 0:00:01
#    --------------------- ------------------ 7.1/12.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.9 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 10.6 MB/s eta 0:00:00
# Downloading scipy-1.16.3-cp313-cp313t-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/38.6 MB 11.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/38.6 MB 11.8 MB/s eta 0:00:03
#    ------- -------------------------------- 6.8/38.6 MB 11.7 MB/s eta 0:00:03
#    --------- ------------------------------ 9.2/38.6 MB 10.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.5/38.6 MB 11.1 MB/s eta 0:00:03
#    -------------- ------------------------- 13.9/38.6 MB 11.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 16.5/38.6 MB 11.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.3/38.6 MB 10.3 MB/s eta 0:00:03
#    -------------------- ------------------- 19.7/38.6 MB 10.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.3/38.6 MB 10.6 MB/s eta 0:00:02
#    ------------------------- -------------- 24.9/38.6 MB 10.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.3/38.6 MB 10.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.3/38.6 MB 10.8 MB/s eta 0:00:01
#    ------------------------------- -------- 30.4/38.6 MB 10.4 MB/s eta 0:00:01
#    -------------------------------- ------- 31.7/38.6 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.6/38.6 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------ --- 34.9/38.6 MB 9.7 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.6 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 9.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
# Successfully installed joblib-1.5.2 numpy-2.3.5 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python3.13t.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313t-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313t-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-py3-none-any.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9.tar.gz (97 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.23 in c:\users\comp\appdata\roaming\python\python313t\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\comp\appdata\roaming\python\python313t\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp313-cp313t-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\comp\appdata\roaming\python\python313t\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\comp\appdata\roaming\python\python313t\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp313-cp313t-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.2 MB 11.1 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.2 MB 11.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 8.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313t-win_amd64.whl (240 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 8.3 MB/s eta 0:00:00
# Downloading pillow-12.0.0-cp313-cp313t-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.0 MB 11.5 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.0 MB 11.5 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 10.6 MB/s eta 0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Building wheels for collected packages: kiwisolver
#   Building wheel for kiwisolver (pyproject.toml): started
#   Building wheel for kiwisolver (pyproject.toml): finished with status 'done'
#   Created wheel for kiwisolver: filename=kiwisolver-1.4.9-cp313-cp313t-win_amd64.whl size=76214 sha256=972262e99855102ccf1ec59319b7724125f2bb6c1c1d6563365dab3947aef4b3
#   Stored in directory: c:\users\comp\appdata\local\pip\cache\wheels\6b\81\87\7c2a05475d686cea00baf11658c3b2589131dd6583fe28f86f
# Successfully built kiwisolver
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python3.13t.exe -m pip install --upgrade pip

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
X = np.array([8,10,12]).reshape(-1,1)
y = np.array([10,13,16])

# create a model
model = LinearRegression()
model.fit(X,y)

# Get the slope (m) and intercept (b)
m = model.coef_[0] #slope
b = model.intercept_ #Intercept
print(f"Slope(m):{m}")
print(f"Intercept (b): {b}")
# Out:
# Slope(m):1.4999999999999998
# Intercept (b): -1.9999999999999982

# %%
# Predict price for a 20-inch pizza
X_new = np.array([20]).reshape(-1,1)
Y_pred = model.predict(X_new)
print(f"Predicted price for a 20-inch pizza: ${Y_pred[0]:.2f}")
# Out:
# Predicted price for a 20-inch pizza: $28.00

# %%
#Plot the data and the regression line
plt.scatter(X,y, color='blue', label='Data Points')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel('Diameter (inches)')
plt.ylabel('Price ($)')
plt.title('Pizza Price Prediction')
plt.legend()
plt.show()

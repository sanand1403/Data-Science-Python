# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# 1. Load CSV data
df = pd.read_csv("Student_Performance.csv")

# 2. Select ONLY 2 features (like age, income)
X = df[["Hours Studied", "Previous Scores"]].values
y = df["Performance Index"].values

# 3. Build 3 trees with Bagging (same as your code)
trees = []

for i in range(3):
    # Bootstrap sample
    indices = np.random.choice(len(X), size=len(X), replace=True)
    X_sample = X[indices]
    y_sample = y[indices]

    # Train a decision tree
    tree = DecisionTreeRegressor()
    tree.fit(X_sample, y_sample)
    trees.append(tree)

# 4. Predict for a new student
# [Hours Studied, Previous Scores]
new_student = np.array([[6, 80]])

predictions = [tree.predict(new_student)[0] for tree in trees]
print("Tree predictions:", predictions)

# Average prediction (regression bagging)
final_prediction = sum(predictions) / len(predictions)
print("Bagging says Performance Index:", round(final_prediction, 2))
# Out:
# Tree predictions: [np.float64(67.7), np.float64(68.76923076923077), np.float64(69.07142857142857)]
# Bagging says Performance Index: 68.51

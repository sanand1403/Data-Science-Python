# %%
# method
# write 'w'

with open ('cwpc.txt','w', encoding='utf-8') as file:
   file.write('Welcome to CWPC\n')
   file.writelines(["Line 2\n","Line 3\n"])

# %%
# read method 'r'
with open('cwpc.txt','r') as file:
    data = file.read()
    print(data)
# Out:
# Welcome to CWPC
# Line 2
# Line 3

# %%
# append()

with open('cwpc.txt','a') as file:
    file.write("\n welcome to python lerning point")

# %%
import pandas as pd
data = pd.read_csv("industry.csv")
data.head()
# Out:
#                         Industry
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive

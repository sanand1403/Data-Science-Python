# %%
# Class
class client:
    def client_info():
        print("Client Name:- Anand")
        print("Client City:- Mumbai")

    def client_account():
        print("SBI Bank")

# %%
# object
c1 = client
c1.client_info()
c1.client_account()
# Out:
# Client Name:- Anand
# Client City:- Mumbai
# SBI Bank

# %%
class Cal:
    def Cal_add():
        result=a+b
        print("Addition of",a,"and",b,"is",result)
    def Cal_sub():
        result=a-b  
        print("Subtraction of",a,"and",b,"is",result)  
    def Cal_mul():
        result=a*b
        print("Multiplication of",a,"and",b,"is",result)
    def Cal_div():
        result=a//b   # '//' means division returns the quotient as a whole number
        print("Division of",a,"and",b,"is",result)
    def Cal_mod():
        result=a%b
        print("Modulus of",a,"and",b,"is",result)

# %%
C1=Cal
a=int(input("Enter first number :"))
b=int(input("Enter second number :"))
C1.Cal_add()
C1.Cal_sub()
C1.Cal_mul()
C1.Cal_div()
C1.Cal_mod()
# Out:
# Addition of 20 and 25 is 45
# Subtraction of 20 and 25 is -5
# Multiplication of 20 and 25 is 500
# Division of 20 and 25 is 0
# Modulus of 20 and 25 is 20

# %%
a = input("Enter name:")
b = int(input("Enter Roll Number:") )
c = int(input("Enter Java marks:"))
d = int(input("Enter Cpp marks:"))
e = int(input("Enter Go marks:"))
f = int(input("Enter Ruby marks:"))
g = int(input("Enter Jsp marks:"))

Sum = c+d+e+f+g 
per = Sum/500*100

print("Name:",a)
print("Roll Number:",b)
print("Total:",Sum)
print("percentage:",per)
# Out:
# Name: anand
# Roll Number: 2345
# Total: 274
# percentage: 54.800000000000004

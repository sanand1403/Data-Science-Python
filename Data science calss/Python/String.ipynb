# %%
data = "Codes with Pankaj"
print (data)
# Out:
# Codes with Pankaj

# %%
print(data[6])
print(data[4:10])
print(data[6:])
print(data[:10])
print(data[:])
# Out:
# w
# s with
# with Pankaj
# Codes with
# Codes with Pankaj

# %%
# Format

name = "joy"
age = 23

print("My name is", name,"and my age is ", age)
print("my name is {0} and my age is {1}" .format(name,age))
print(f'my name is {name} and age is {age}')
# Out:
# My name is joy and my age is  23
# my name is joy and my age is 23
# my name is joy and age is 23

# %%
data = "Codes with Pankaj"
# 1. upper() converts the string to upper case
print(data.upper())
# 2. lower() converts the string to lower case
print(data.lower())
# 3. partition() returns a tuple
print(data.partition("n"))
# 4. replace() replaces substring inside
print(data.replace("Pankaj","Python"))
# 5. find() returns the index of first occurrence of substring
print(data.find("P"))
# 6. rstrip() removes trailing characters
data = "python  "
print(data.rstrip(),"programming ")
# 7. split() splits string from left
data = "python is the best programming language"
print(data.split(" "))
# 8. startswith() checks if the string starts with the specified string
print(data.startswith("thon"))
# 9. isnumeric() checks numeric characters
data = "989078"
print(data.isnumeric())
# 10. index() returns index of substring
data = "python is best programming language"
print(data.index("l"))
# Out:
# CODES WITH PANKAJ
# codes with pankaj
# ('Codes with Pa', 'n', 'kaj')
# Codes with Python
# 11
# python programming
# ['python', 'is', 'the', 'best', 'programming', 'language']
# False
# True
# 27

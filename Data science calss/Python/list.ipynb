# %%
# create an empty list
data = []
print(data)
# check type
print(type(data))
# Out:
# []
# <class 'list'>

# %%
data = [11,22,33,44,55,66]
data = ["java","c++","go","jsp"]
data = [33,"java",8.9,True]

# %%
data = [11,22,33,44,55,66]
print(data[3])
print(data[-2])
print(data[2:5])
print(data[-5:-2])
print(data[:-3])
# Out:
# 44
# 55
# [33, 44, 55]
# [22, 33, 44]
# [11, 22, 33]

# %%
# add new data
data.append(99)
print(data)
# Out:
# [11, 22, 33, 44, 55, 66, 99]

# %%
# add more then 1 data
data.extend([20,21,23])
print(data)
# Out:
# [11, 22, 33, 44, 55, 66, 99, 20, 21, 23]

# %%
# remove data
data.pop(2)
print(data)
# Out:
# [11, 22, 44, 55, 66, 99, 20, 21, 23]

# %%
data.pop()
print(data)
# Out:
# [11, 22, 44, 55, 66, 99, 20, 21]

# %%
data.remove(22)
print(data)
# Out:
# [11, 44, 55, 66, 99, 20, 21]

# %%
# update record
data[4] = 400
print(data)
# Out:
# [11, 44, 55, 66, 400, 20, 21]

# %%
# insert into list
data.insert(2,100)
print(data)
# Out:
# [11, 44, 100, 55, 66, 400, 20, 21]

# %%
print(len(data))
print(sum(data))
print(min(data))
print(max(data))
# Out:
# 8
# 717
# 11
# 400
